# %% [markdown]
# Gold price prediction

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
gold_price = yf.Ticker("GC=F")
gold_price
# Out:
# yfinance.Ticker object <GC=F>

# %%
df = gold_price.history(period="10y")

# %%
df.describe()
# Out:
#               Open         High          Low        Close         Volume  \
# count  2514.000000  2514.000000  2514.000000  2514.000000    2514.000000
# mean   1751.526610  1760.291846  1743.289459  1752.013444    5260.307876
# std     557.628201   561.950369   554.105486   558.565198   28983.502898
# min    1053.699951  1062.000000  1046.199951  1050.800049       0.000000
# 25%    1286.825043  1291.375031  1283.049988  1287.099976      51.000000
# 50%    1730.000000  1739.750000  1721.600037  1729.250000     201.500000
# 75%    1935.899994  1946.149963  1926.300018  1935.350006     621.750000
# max    3769.800049  3792.300049  3751.899902  3783.100098  386334.000000
#
#        Dividends  Stock Splits
# count     2514.0        2514.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
df = pd.DataFrame(df)
df.plot(y='Close', use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2015-09-25 00:00:00-04:00  1149.800049  1149.800049  1143.400024  1146.000000
# 2015-09-28 00:00:00-04:00  1133.199951  1133.199951  1132.000000  1132.000000
# 2015-09-29 00:00:00-04:00  1132.199951  1134.400024  1124.300049  1127.099976
# 2015-09-30 00:00:00-04:00  1124.300049  1126.000000  1112.099976  1115.500000
# 2015-10-01 00:00:00-04:00  1115.199951  1119.000000  1113.300049  1114.199951
#
#                            Volume  Dividends  Stock Splits
# Date
# 2015-09-25 00:00:00-04:00      56        0.0           0.0
# 2015-09-28 00:00:00-04:00    4346        0.0           0.0
# 2015-09-29 00:00:00-04:00    2417        0.0           0.0
# 2015-09-30 00:00:00-04:00     865        0.0           0.0
# 2015-10-01 00:00:00-04:00    1181        0.0           0.0

# %%
oil_price = yf.Ticker("CL=F")
oil_df = oil_price.history(period="10y")

# Convert to DataFrame and plot
oil_df = pd.DataFrame(oil_df)
plt.figure(figsize=(12, 6))
oil_df.plot(y='Close', use_index=True, title='WTI Crude Oil Price History')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.grid(True)

# Display first few rows
print("Oil price data head:")
oil_df.head()
# Out:
# Oil price data head:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2015-09-25 00:00:00-04:00  45.049999  46.380001  44.860001  45.700001  338622
# 2015-09-28 00:00:00-04:00  45.380001  45.500000  44.299999  44.430000  273906
# 2015-09-29 00:00:00-04:00  44.500000  45.700001  44.299999  45.230000  265176
# 2015-09-30 00:00:00-04:00  44.919998  45.849998  44.680000  45.090000  355853
# 2015-10-01 00:00:00-04:00  45.380001  47.099998  44.630001  44.740002  478979
#
#                            Dividends  Stock Splits
# Date
# 2015-09-25 00:00:00-04:00        0.0           0.0
# 2015-09-28 00:00:00-04:00        0.0           0.0
# 2015-09-29 00:00:00-04:00        0.0           0.0
# 2015-09-30 00:00:00-04:00        0.0           0.0
# 2015-10-01 00:00:00-04:00        0.0           0.0

# %%
# Get USD Index data
usd_price = yf.Ticker("DX-Y.NYB")
usd_df = usd_price.history(period="10y")

# Convert to DataFrame and plot
usd_df = pd.DataFrame(usd_df)
plt.figure(figsize=(12, 6))
usd_df.plot(y='Close', use_index=True, title='US Dollar Index History')
plt.xlabel('Date')
plt.ylabel('USD Index Value')
plt.grid(True)

# Display first few rows
print("USD Index data head:")
usd_df.head()
# Out:
# USD Index data head:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2015-09-25 00:00:00-04:00  96.250000  96.699997  96.120003  96.269997       0
# 2015-09-28 00:00:00-04:00  96.260002  96.500000  95.900002  96.029999       0
# 2015-09-29 00:00:00-04:00  96.029999  96.239998  95.709999  95.889999       0
# 2015-09-30 00:00:00-04:00  95.919998  96.410004  95.849998  96.349998       0
# 2015-10-01 00:00:00-04:00  96.269997  96.489998  95.970001  96.190002       0
#
#                            Dividends  Stock Splits
# Date
# 2015-09-25 00:00:00-04:00        0.0           0.0
# 2015-09-28 00:00:00-04:00        0.0           0.0
# 2015-09-29 00:00:00-04:00        0.0           0.0
# 2015-09-30 00:00:00-04:00        0.0           0.0
# 2015-10-01 00:00:00-04:00        0.0           0.0

# %%
df = gold_price.history(period="1y")
oil_df = oil_price.history(period="1y")
usd_df = usd_price.history(period="1y")

# Normalize the closing prices to start at 100
gold_normalized = df['Close'] / df['Close'].iloc[0] * 100
oil_normalized = oil_df['Close'] / oil_df['Close'].iloc[0] * 100
usd_normalized = usd_df['Close'] / usd_df['Close'].iloc[0] * 100

# Create the combined plot
plt.figure(figsize=(15, 8))
plt.plot(gold_normalized.index, gold_normalized, label='Gold', color='gold')
plt.plot(oil_normalized.index, oil_normalized, label='Oil', color='brown')
plt.plot(usd_normalized.index, usd_normalized, label='USD Index', color='green')

plt.title('Normalized Prices: Gold, Oil, and USD Index (Base=100)')
plt.xlabel('Date')
plt.ylabel('Normalized Price')
plt.grid(True)
plt.legend()      
plt.show()

# Print correlation matrix
correlation_df = pd.DataFrame({
    'Gold': gold_normalized,
    'Oil': oil_normalized,
    'USD': usd_normalized
})
print("\nCorrelation Matrix:")
print(correlation_df.corr())
# Out:
# Correlation Matrix:
#           Gold       Oil       USD
# Gold  1.000000 -0.664768 -0.862478
# Oil  -0.664768  1.000000  0.679805
# USD  -0.862478  0.679805  1.000000

# %%
# Normalize the closing prices to start at 100 (not 10)
df = gold_price.history(period="5y")
oil_df = oil_price.history(period="5y")
usd_df = usd_price.history(period="5y")

gold_normalized = df['Close'] / df['Close'].iloc[0] * 100
oil_normalized = oil_df['Close'] / oil_df['Close'].iloc[0] * 100
usd_normalized = usd_df['Close'] / usd_df['Close'].iloc[0] * 100

# Create the combined plot
plt.figure(figsize=(15, 8))
plt.plot(gold_normalized.index, gold_normalized, label='Gold', color='gold')
plt.plot(oil_normalized.index, oil_normalized, label='Oil', color='brown')
plt.plot(usd_normalized.index, usd_normalized, label='USD Index', color='green')

plt.title('10-Year Normalized Prices: Gold, Oil, and USD Index (Base=100)')
plt.xlabel('Date')
plt.ylabel('Normalized Price (Base=100)')
plt.grid(True)
plt.legend()      

# Add text with date range
start_date = gold_normalized.index[0].strftime('%Y-%m-%d')
end_date = gold_normalized.index[-1].strftime('%Y-%m-%d')
plt.text(0.02, 0.98, f'Period: {start_date} to {end_date}', 
         transform=plt.gca().transAxes, 
         fontsize=9)

plt.show()

# Print correlation matrix with period information
print(f"\nCorrelation Matrix ({start_date} to {end_date}):")
print(correlation_df.corr())
# Out:
# Correlation Matrix (2020-09-25 to 2025-09-25):
#           Gold       Oil       USD
# Gold  1.000000 -0.664768 -0.862478
# Oil  -0.664768  1.000000  0.679805
# USD  -0.862478  0.679805  1.000000

# %%
#gold price last 10 days
df = gold_price.history(period="100d")
plt.figure(figsize=(10, 5))
plt.plot(df.index, df['Close'], marker='o', linestyle='-', color='gold')
plt.title('Gold Price - Last 10 Days')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()

# %%
#last 10 days gold moving average
df['MA10'] = df['Close'].rolling(window=10).mean()
#plotting moving average
plt.figure(figsize=(10, 5))
plt.plot(df.index, df['Close'], label='Close Price', color='gold')
plt.plot(df.index, df['MA10'], label='10-Day MA', color='blue', linestyle='--')
plt.title('Gold Price with 10-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
df['MA10']
df.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2025-09-19 00:00:00-04:00  3659.000000  3685.899902  3658.199951  3671.500000
# 2025-09-22 00:00:00-04:00  3688.199951  3748.199951  3688.000000  3740.699951
# 2025-09-23 00:00:00-04:00  3747.000000  3786.000000  3740.000000  3780.600098
# 2025-09-24 00:00:00-04:00  3769.800049  3772.500000  3732.100098  3732.100098
# 2025-09-25 00:00:00-04:00  3768.300049  3792.300049  3751.899902  3783.600098
#
#                            Volume  Dividends  Stock Splits         MA10
# Date
# 2025-09-19 00:00:00-04:00     211        0.0           0.0  3657.939990
# 2025-09-22 00:00:00-04:00     410        0.0           0.0  3668.199976
# 2025-09-23 00:00:00-04:00     627        0.0           0.0  3681.929980
# 2025-09-24 00:00:00-04:00     627        0.0           0.0  3690.779980
# 2025-09-25 00:00:00-04:00  245828        0.0           0.0  3705.450000

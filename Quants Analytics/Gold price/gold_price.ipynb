# %% [markdown]
# Gold price prediction

# %%
import yfinance as yf                   
import pandas as pd
import matplotlib.pyplot as plt

# %%
gold_price = yf.Ticker("GC=F")
gold_price
# Out:
# yfinance.Ticker object <GC=F>

# %%
df = gold_price.history(period="10y")

# %%
df.describe()
# Out:
#               Open         High          Low        Close         Volume  \
# count  2514.000000  2514.000000  2514.000000  2514.000000    2514.000000
# mean   1757.946698  1766.773867  1749.692045  1758.460102    5175.019889
# std     565.843137   570.299110   562.332692   566.867327   28585.597301
# min    1053.699951  1062.000000  1046.199951  1050.800049       0.000000
# 25%    1287.475006  1292.000000  1284.000000  1288.649994      51.000000
# 50%    1732.350037  1741.699951  1722.750000  1731.900024     202.000000
# 75%    1938.924988  1947.350006  1928.750031  1937.950012     622.000000
# max    3863.500000  3891.899902  3853.699951  3880.800049  386334.000000
#
#        Dividends  Stock Splits
# count     2514.0        2514.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
df = pd.DataFrame(df)
df.plot(y='Close', use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2015-10-05 00:00:00-04:00  1137.099976  1141.699951  1132.500000  1138.099976
# 2015-10-06 00:00:00-04:00  1136.300049  1150.000000  1136.300049  1146.800049
# 2015-10-07 00:00:00-04:00  1147.599976  1152.900024  1143.000000  1149.000000
# 2015-10-08 00:00:00-04:00  1142.699951  1146.699951  1138.699951  1144.699951
# 2015-10-09 00:00:00-04:00  1151.599976  1157.199951  1151.599976  1156.300049
#
#                            Volume  Dividends  Stock Splits
# Date
# 2015-10-05 00:00:00-04:00     226        0.0           0.0
# 2015-10-06 00:00:00-04:00     145        0.0           0.0
# 2015-10-07 00:00:00-04:00     104        0.0           0.0
# 2015-10-08 00:00:00-04:00     138        0.0           0.0
# 2015-10-09 00:00:00-04:00      22        0.0           0.0

# %%
oil_price = yf.Ticker("CL=F")
oil_df = oil_price.history(period="10y")

# Convert to DataFrame and plot
oil_df = pd.DataFrame(oil_df)
plt.figure(figsize=(12, 6))
oil_df.plot(y='Close', use_index=True, title='WTI Crude Oil Price History')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.grid(True)

# Display first few rows
print("Oil price data head:")
oil_df.head()
# Out:
# Oil price data head:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2015-10-05 00:00:00-04:00  45.650002  46.939999  45.209999  46.259998  323061
# 2015-10-06 00:00:00-04:00  46.200001  49.080002  45.730000  48.529999  453101
# 2015-10-07 00:00:00-04:00  49.000000  49.709999  47.700001  47.810001  547488
# 2015-10-08 00:00:00-04:00  48.110001  50.070000  47.759998  49.430000  509760
# 2015-10-09 00:00:00-04:00  49.689999  50.919998  49.169998  49.630001  508680
#
#                            Dividends  Stock Splits
# Date
# 2015-10-05 00:00:00-04:00        0.0           0.0
# 2015-10-06 00:00:00-04:00        0.0           0.0
# 2015-10-07 00:00:00-04:00        0.0           0.0
# 2015-10-08 00:00:00-04:00        0.0           0.0
# 2015-10-09 00:00:00-04:00        0.0           0.0

# %%
# Get USD Index data
usd_price = yf.Ticker("DX-Y.NYB")
usd_df = usd_price.history(period="10y")

# Convert to DataFrame and plot
usd_df = pd.DataFrame(usd_df)
plt.figure(figsize=(12, 6))
usd_df.plot(y='Close', use_index=True, title='US Dollar Index History')
plt.xlabel('Date')
plt.ylabel('USD Index Value')
plt.grid(True)

# Display first few rows
print("USD Index data head:")
usd_df.head()
# Out:
# USD Index data head:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2015-10-05 00:00:00-04:00  95.820000  96.169998  95.449997  96.110001       0
# 2015-10-06 00:00:00-04:00  96.050003  96.160004  95.400002  95.459999       0
# 2015-10-07 00:00:00-04:00  95.470001  95.699997  95.330002  95.500000       0
# 2015-10-08 00:00:00-04:00  95.570000  95.610001  94.980003  95.320000       0
# 2015-10-09 00:00:00-04:00  95.230003  95.339996  94.690002  94.809998       0
#
#                            Dividends  Stock Splits
# Date
# 2015-10-05 00:00:00-04:00        0.0           0.0
# 2015-10-06 00:00:00-04:00        0.0           0.0
# 2015-10-07 00:00:00-04:00        0.0           0.0
# 2015-10-08 00:00:00-04:00        0.0           0.0
# 2015-10-09 00:00:00-04:00        0.0           0.0

# %%
df = gold_price.history(period="1y")
oil_df = oil_price.history(period="1y")
usd_df = usd_price.history(period="1y")

# Normalized the closing prices to start at 100
gold_normalized = df['Close'] / df['Close'].iloc[0] * 100
oil_normalized = oil_df['Close'] / oil_df['Close'].iloc[0] * 100
usd_normalized = usd_df['Close'] / usd_df['Close'].iloc[0] * 100

plt.figure(figsize=(15, 8))
plt.plot(gold_normalized.index, gold_normalized, label='Gold', color='gold')
plt.plot(oil_normalized.index, oil_normalized, label='Oil', color='brown')
plt.plot(usd_normalized.index, usd_normalized, label='USD Index', color='green')

plt.title('Normalized Prices: Gold, Oil, and USD Index (Base=100)')
plt.xlabel('Date')
plt.ylabel('Normalized Price')
plt.grid(True)
plt.legend()      
plt.show()

#correlation matrix
correlation_df = pd.DataFrame({
    'Gold': gold_normalized,
    'Oil': oil_normalized,
    'USD': usd_normalized
})
print("\nCorrelation Matrix:")
print(correlation_df.corr())
# Out:
# Correlation Matrix:
#           Gold       Oil       USD
# Gold  1.000000 -0.676954 -0.888175
# Oil  -0.676954  1.000000  0.696315
# USD  -0.888175  0.696315  1.000000

# %%
# Normalize the closing prices to start at 100 (not 10)
df = gold_price.history(period="5y")
oil_df = oil_price.history(period="5y")
usd_df = usd_price.history(period="5y")

gold_normalized = df['Close'] / df['Close'].iloc[0] * 100
oil_normalized = oil_df['Close'] / oil_df['Close'].iloc[0] * 100
usd_normalized = usd_df['Close'] / usd_df['Close'].iloc[0] * 100

# Create the combined plot
plt.figure(figsize=(15, 8))
plt.plot(gold_normalized.index, gold_normalized, label='Gold', color='gold')
plt.plot(oil_normalized.index, oil_normalized, label='Oil', color='brown')
plt.plot(usd_normalized.index, usd_normalized, label='USD Index', color='green')

plt.title('10-Year Normalized Prices: Gold, Oil, and USD Index (Base=100)')
plt.xlabel('Date')
plt.ylabel('Normalized Price (Base=100)')
plt.grid(True)
plt.legend()      

# Add text with date range
start_date = gold_normalized.index[0].strftime('%Y-%m-%d')
end_date = gold_normalized.index[-1].strftime('%Y-%m-%d')
plt.text(0.02, 0.98, f'Period: {start_date} to {end_date}', 
         transform=plt.gca().transAxes, 
         fontsize=9)

plt.show()


print(f"\nCorrelation Matrix ({start_date} to {end_date}):")
print(correlation_df.corr())
# Out:
# Correlation Matrix (2020-10-05 to 2025-10-03):
#           Gold       Oil       USD
# Gold  1.000000 -0.676954 -0.888175
# Oil  -0.676954  1.000000  0.696315
# USD  -0.888175  0.696315  1.000000

# %%
#gold price last 10 days
df = gold_price.history(period="50y")
plt.figure(figsize=(10, 5))
plt.plot(df.index, df['Close'], marker='o', linestyle='-', color='gold')
plt.title('Gold Price - Last 10 Days')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()

# %%
#last 10 days gold moving average
df['MA10'] = df['Close'].rolling(window=10).mean()
#plotting moving average
plt.figure(figsize=(10, 5))
plt.plot(df.index, df['Close'], label='Close Price', color='gold')
plt.plot(df.index, df['MA10'], label='10-Day MA', color='blue', linestyle='--')
plt.title('Gold Price with 10-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
df['MA10']
df.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2025-09-29 00:00:00-04:00  3754.800049  3827.600098  3754.800049  3820.899902
# 2025-09-30 00:00:00-04:00  3827.500000  3865.500000  3793.399902  3840.800049
# 2025-10-01 00:00:00-04:00  3863.500000  3891.899902  3853.300049  3867.500000
# 2025-10-02 00:00:00-04:00  3856.199951  3888.600098  3823.699951  3839.699951
# 2025-10-03 00:00:00-04:00  3855.199951  3886.800049  3853.699951  3880.800049
#
#                            Volume  Dividends  Stock Splits         MA10
# Date
# 2025-09-29 00:00:00-04:00    8860        0.0           0.0  3727.239990
# 2025-09-30 00:00:00-04:00    1611        0.0           0.0  3742.430005
# 2025-10-01 00:00:00-04:00    1778        0.0           0.0  3761.000000
# 2025-10-02 00:00:00-04:00    3418        0.0           0.0  3780.600000
# 2025-10-03 00:00:00-04:00    3418        0.0           0.0  3801.530005

# %%
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2000-08-30 00:00:00-04:00  273.899994  273.899994  273.899994  273.899994
# 2000-08-31 00:00:00-04:00  274.799988  278.299988  274.799988  278.299988
# 2000-09-01 00:00:00-04:00  277.000000  277.000000  277.000000  277.000000
# 2000-09-05 00:00:00-04:00  275.799988  275.799988  275.799988  275.799988
# 2000-09-06 00:00:00-04:00  274.200012  274.200012  274.200012  274.200012
#
#                            Volume  Dividends  Stock Splits  MA10
# Date
# 2000-08-30 00:00:00-04:00       0        0.0           0.0   NaN
# 2000-08-31 00:00:00-04:00       0        0.0           0.0   NaN
# 2000-09-01 00:00:00-04:00       0        0.0           0.0   NaN
# 2000-09-05 00:00:00-04:00       2        0.0           0.0   NaN
# 2000-09-06 00:00:00-04:00       0        0.0           0.0   NaN

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import pmdarima as pm

# %%
df.index
# Out:
# DatetimeIndex(['2015-10-05 00:00:00-04:00', '2015-10-06 00:00:00-04:00',
#                '2015-10-07 00:00:00-04:00', '2015-10-08 00:00:00-04:00',
#                '2015-10-09 00:00:00-04:00', '2015-10-12 00:00:00-04:00',
#                '2015-10-13 00:00:00-04:00', '2015-10-14 00:00:00-04:00',
#                '2015-10-15 00:00:00-04:00', '2015-10-16 00:00:00-04:00',
#                ...
#                '2025-09-22 00:00:00-04:00', '2025-09-23 00:00:00-04:00',
#                '2025-09-24 00:00:00-04:00', '2025-09-25 00:00:00-04:00',
#                '2025-09-26 00:00:00-04:00', '2025-09-29 00:00:00-04:00',
#                '2025-09-30 00:00:00-04:00', '2025-10-01 00:00:00-04:00',
#                '2025-10-02 00:00:00-04:00', '2025-10-03 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=2514, freq=None)

# %%
plot_acf(df['Close'], lags=30)
plt.title('ACF (Autocorrelation Function)')
plt.show()

plot_pacf(df['Close'], lags=30, method='ols')
plt.title('PACF (Partial Autocorrelation Function)')
plt.show()

# %%
model = ARIMA(df['Close'], order=(2, 1, 0))  # replace with your chosen order, e.g., (1,1,1)
model_fit = model.fit()

# Forecast next 5 days
forecast = model_fit.forecast(steps=5)

# Create future dates based on current index
import pandas as pd
future_dates = pd.date_range(df.index[-1] + pd.Timedelta(days=1), periods=5)

# Prepare result DataFrame
result_df = pd.DataFrame({'Date': future_dates, 'Forecasted_Close': forecast.values})

print(result_df)
# Out:
# c:\Users\niran\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\niran\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\niran\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                        Date  Forecasted_Close
# 0 2025-10-04 00:00:00-04:00       3880.112258
# 1 2025-10-05 00:00:00-04:00       3880.074080
# 2 2025-10-06 00:00:00-04:00       3880.075591
# 3 2025-10-07 00:00:00-04:00       3880.075612
# 4 2025-10-08 00:00:00-04:00       3880.075609
# c:\Users\niran\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\niran\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
last_close = df['Close'].iloc[-1]

# Calculate percentage increase for each predicted day
result_df['Percent_Increase'] = ((result_df['Forecasted_Close'] - last_close) / last_close) * 100


result_df['Percent_Increase'] = result_df['Percent_Increase'].round(2)

print(result_df[['Date', 'Forecasted_Close', 'Percent_Increase']])
# Out:
#                        Date  Forecasted_Close  Percent_Increase
# 0 2025-10-04 00:00:00-04:00       3880.112258             -0.02
# 1 2025-10-05 00:00:00-04:00       3880.074080             -0.02
# 2 2025-10-06 00:00:00-04:00       3880.075591             -0.02
# 3 2025-10-07 00:00:00-04:00       3880.075612             -0.02
# 4 2025-10-08 00:00:00-04:00       3880.075609             -0.02

# %%
result_df.head()
# Out:
#                        Date  Forecasted_Close  Percent_Increase
# 0 2025-10-04 00:00:00-04:00       3880.112258             -0.02
# 1 2025-10-05 00:00:00-04:00       3880.074080             -0.02
# 2 2025-10-06 00:00:00-04:00       3880.075591             -0.02
# 3 2025-10-07 00:00:00-04:00       3880.075612             -0.02
# 4 2025-10-08 00:00:00-04:00       3880.075609             -0.02

# %%
last_date = df.index[-1]

# 1 week ago
date_1w_ago = last_date - pd.Timedelta(weeks=1)
price_1w_ago = df.loc[df.index <= date_1w_ago, 'Close'].iloc[-1]

# 1 month ago (approx 30 days)
date_1m_ago = last_date - pd.Timedelta(days=30)
price_1m_ago = df.loc[df.index <= date_1m_ago, 'Close'].iloc[-1]

# Current price
current_price = df['Close'].iloc[-1]

# Calculate percentage change
change_1w = ((current_price - price_1w_ago) / price_1w_ago) * 100
change_1m = ((current_price - price_1m_ago) / price_1m_ago) * 100

print(f"Price change in last 1 week: {change_1w:.2f}%")
print(f"Price change in last 1 month: {change_1m:.2f}%")
# Out:
# Price change in last 1 week: 2.79%
# Price change in last 1 month: 8.00%
